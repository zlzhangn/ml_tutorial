# %%
# 目标函数
def f(x):
    return x ** 2 + 6 * x + 4

# 梯度函数（导函数）
def gradient(x):
    return 2 * x + 6

# %%
# 用列表记录所有点的轨迹
x_list = []
y_list = []

# 1. 初始化参数(自变量)和学习率
x = 1
alpha = 0.1

# 4. 重复迭代100次
for i in range(100):
    y = f(x)
    print(f"x={x}\ty={y}")
    x_list.append(x)
    y_list.append(y)
    
    # 2. 计算梯度
    grad = gradient(x)

    # 3. 更新参数
    x = x - alpha * grad

# print(x_list)
# print(y_list)
# Out:
# x=1	y=11
# x=0.19999999999999996	y=5.24
# x=-0.44000000000000017	y=1.553599999999999
# x=-0.9520000000000001	y=-0.8056960000000002
# x=-1.3616000000000001	y=-2.315645440000001
# x=-1.6892800000000001	y=-3.2820130816000006
# x=-1.951424	y=-3.9004883722240002
# x=-2.1611392	y=-4.2963125582233594
# x=-2.32891136	y=-4.54964003726295
# x=-2.463129088	y=-4.711769623848287
# x=-2.5705032704	y=-4.8155325592629055
# x=-2.6564026163200003	y=-4.8819408379282585
# x=-2.725122093056	y=-4.9244421362740844
# x=-2.7800976744448	y=-4.951642967215415
# x=-2.82407813955584	y=-4.969051499017864
# x=-2.8592625116446717	y=-4.980192959371433
# x=-2.8874100093157375	y=-4.987323493997719
# x=-2.90992800745259	y=-4.991887036158538
# x=-2.927942405962072	y=-4.994807703141467
# x=-2.9423539247696575	y=-4.996676930010539
# x=-2.953883139815726	y=-4.997873235206743
# x=-2.9631065118525806	y=-4.998638870532318
# x=-2.9704852094820646	y=-4.999128877140684
# x=-2.9763881675856516	y=-4.9994424813700356
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-5, 1, 0.01)

plt.plot(x, f(x))
plt.plot(x_list, y_list, 'r')    # 画出点的移动轨迹
plt.scatter(x_list, y_list, color='red') # 画出点

plt.show()
